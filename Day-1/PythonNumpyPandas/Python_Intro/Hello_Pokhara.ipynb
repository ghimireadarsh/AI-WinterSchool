# %%
print ('Hello Pokhara')
# Out:
# Hello Pokhara

# %%
print("Hello Pokhara")
# Out:
# Hello Pokhara

# %%
#print("Hello Pokhara")

# %% [markdown]
# ## Say Hello to your home town.

# %%
print('Hello Kathmandu')
# Out:
# Hello Kathmandu

# %% [markdown]
# ## Say Hello to the capital of Nepal.

# %%
print('Hello Kathmandu')
# Out:
# Hello Kathmandu
