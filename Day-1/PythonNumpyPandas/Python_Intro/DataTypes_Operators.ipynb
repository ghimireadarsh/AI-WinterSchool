# %% [markdown]
# # Basic Data Types

# %%
# integers
x = 3

# %%
print(x)       # Prints "3"
print(type(x)) # Prints "<class 'int'>"
# Out:
# 3
# <class 'int'>

# %%
# floating numbers
y = 2.5

print(y)
print(type(y))
# Out:
# 2.5
# <class 'float'>

# %%
# Strings

h = 'hello'    # String literals can use single quotes
w = "world"    # or double quotes; it does not matter.

print(h)       # Prints "hello"
print(type(h))  # String length; prints "5"
# Out:
# hello
# <class 'str'>

# %%
t = True
f = False

print(t)
print(type(t)) # Prints "<class 'bool'>"
# Out:
# True
# <class 'bool'>

# %% [markdown]
# # Basic Operations
#
# numeric, shorthand, string

# %%
# numeric operators

x = 3

print(x + 1)   # Addition; prints "4"
print(x - 1)   # Subtraction; prints "2"
print(x * 2)   # Multiplication; prints "6"
print(x ** 2)  # Exponentiation; prints "9"
# Out:
# 4
# 2
# 6
# 9

# %%
# shorthand operators

x += 1
print(x)  # Prints "4"

x *= 2
print(x)  # Prints "8"
# Out:
# 4
# 8

# %%
# boolean operators

t = True
f = False

print(t and f) # Logical AND; prints "False"
print(t or f)  # Logical OR; prints "True"
print(not t)   # Logical NOT; prints "False"
print(t != f)  # Logical XOR; prints "True"
# Out:
# False
# True
# False
# True

# %%
# string concatenation
hw = 'hello' + ' ' + 'pokhara'  # String concatenation
print(hw)  # prints "hello world"
# Out:
# hello pokhara

# %%
s = "Pokhara"

print(len(s))  # String length
print(s.capitalize())  # Capitalize a string
print(s.upper())       # Convert a string to uppercase
print(s.replace('ra', 'reli'))  # Replace all instances of one substring with another;
print('  Pokhara '.strip())  # Strip leading and trailing whitespace
# Out:
# 7
# Pokhara
# POKHARA
# Pokhareli
# Pokhara

# %%
# string formatting

city = "Pokhara"
print("Hello, %s!" % city)
# Out:
# Hello, Pokhara!

# %%
city1 = "Pokhara"
city2 = "Kathmandu"
distance = 200
unit = "kilometers"
print("%s is %d %s away from %s." % (city1, distance, unit, city2))
# Out:
# Pokhara is 200 kilometers away from Kathmandu.

# %% [markdown]
# # Functions and Iterations

# %%
def my_function(city):
    print(city)
    return 'Hello '+ city + "!"

print(my_function('Pokhara'))
print(my_function('Kathmandu'))
print(my_function('Tashkent'))
# Out:
# Pokhara
# Hello Pokhara!
# Kathmandu
# Hello Kathmandu!
# Tashkent
# Hello Tashkent!

# %%
def my_loop_function(city):
  for x in city:
    print(x)

cities = ["Pokhara", "Kathmandu", "Tashkent"]

my_loop_function(cities)
# Out:
# Pokhara
# Kathmandu
# Tashkent

# %% [markdown]
# # Exercise
#
# Write a function that takes 'city name' as input and prints: 'city name' must be a beautiful city. But we bet not as beautiful as Pokhara.

# %%
def returner(cities):
    for i in cities:
        print('{} must be a beautiful city. But we bet not as beautiful as Pokhara.'.format(i))

cities = ['Kathmandu', 'New York', 'Paris']
returner(cities)
# Out:
# Kathmandu must be a beautiful city. But we bet not as beautiful as Pokhara.
# New York must be a beautiful city. But we bet not as beautiful as Pokhara.
# Paris must be a beautiful city. But we bet not as beautiful as Pokhara.
